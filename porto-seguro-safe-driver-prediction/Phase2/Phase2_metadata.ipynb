# %% [markdown]
# <div class="alert alert-block alert-warning">
# <center><b>Project Diary（2022.Aug.17）</b></center>
#
# Phase 2：【Data Management & Metadata Analysis】
#
#
# **Phase 2 Goals：**
#    - Master when and how to use 5 diftinct variable types
#    - Understand and use Metadata and its structures
#    - Master Metadata to analyze data
#    - Strengthen Matplotli Use
#
# **Difficulty（out of 5）：**⭐⭐⭐
#
#
# Good Luck!
# </div>

# %% [markdown]
# In our project, there are 58 features, and we need to use 58 thse features to predict the probability that the driver will initiate a claim next year. In the previous phase, we have discussed and analyzed why we do this.
#
# which includs but not limited to:
#
# For the

# %% [markdown]
# In our project, there are 58 features, and we need to use 58 thse features to predict the probability that the driver will initiate a claim next year. In the previous phase, we have discussed and analyzed why we do this.
#
# which includs but not limited to:
#
# - **For the driver：** It can help drivers reduce unnecessary insurance expenses, improve drivers' rational willingness to purchase insurance.
# - **For the company：** It can help companies to price insurance products more reasonably, help companies to more accurately analyze the customers' needs to buy insurance, thus improve the competitiveness of the industry.
#
# - **For development：** It can help companies narrow the scope of research on customer's characteristics, greatly save research costs, expand research investment in elite characteristics, and respond more quickly to new user claims.

# %% [markdown]
# Now for this phase, we are here to inversigate Metadata!
#
# - <font color=red>What is it？</font>
# - <font color=red>Why it matters in many projects？</font>
# - <font color=red>Advantages？</font>
# - <font color=red>Highlights？</font>
#
# In this phase, we would dive into these questions 1 by 1!

# %% [markdown]
# ## The Relationship and Difference of 5 Types of Variables
#
# First of all, in order to protect customers' information, this project does not disclose the specific meaning of these 58 analysis features of the data. In other words, we cannot perform an intuitive analysis from the [column name], and we cannot tell which features are effective and useful for prediction!
#
# For example: I want to predict whether a person is male or female. We may decide by many intuitive dimensions such as hair length, height, and weight. We will evaluate the degree of influence (weight) of the characteristics according to natural consciousness and experience. Usually such approach turns out to be effective.
#
# However, the meanings of all dimensions here are pretty vague, and we cannot make subjective judgments about them. We can only disassemble and integrate them through different variable types, looking through them to finding the hidden connections.

# %% [markdown]
# With `df.info()`, we can tell there are 2 data types for distinct variables. -`int64` and  `float64`, what does this mean?
#
# Intuitively, this means that the data has been proccesed before releasing, and the all the data has been converted to integers (also to protect customers privacy).

# %% [markdown]
# Then, for these 58 features, what are the possible data tyes for them?
#
# **5 Major Data Types (also known as: Levels of Measurement)**
#
# Briefly as：
#
# - Binary ==> 0 or 1
#     - only 2 outputs：0/1
#
# - Nominal ==> categorical, non-ordered
#     - most common data type，**not ordered**
#     - e.g. a list of country names (China, US, UK, Canada etc.) **there is no specific ordering between them.**
#
# - Ordinal ==> categorical, but ordered
#     - just like orderd nominal
#     - e.g. grade ranking of students (Emma 1st，Lily 2nd，John 3rd etc.) **the ordering here means the ranking of thier grades, ordinal**
#
# - Interval ==> continuous, do not have an absolute zero point
#     - countinuous data，can be included in stat calculations to compare magnitude and quantify measurements
#     - e.g. temperature (we can say 40C > 20C，but we cannot say it is twice 20C) **interval data does not have an absolute zero point！**
#
# - Ratio ==> continuous, acommadate a zero point
#     - countinuous data, can be included in any stat calculations to compare magnitude and quantify measurements
#     - e.g. height (200cm > 100cm, and we can also say 200cm = 2*100cm) **ratio data has an absolute zero point！**

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 1 </b>Exercise
#
# Classif these variables as binary、nominal、ordinal、interval、ratio.
#
#
# </div>

# %% [markdown]
# |  id  |                         Question                         | Your Answer |
# | :--: | :------------------------------------------------------: | :---------: |
# |  1   |                 Flavors of frozen yogurt                 |             |
# |  2   |           Amount of money in savings accounts            |             |
# |  3   |            Letter grades on an English essay             |             |
# |  4   |                        Religions                         |             |
# |  5   |                 Commuting times to work                  |             |
# |  6   |             Ages (in years) of art students              |             |
# |  7   |               Ice cream flavor preference                |             |
# |  8   |           Years of important historical events           |             |
# |  9   | Instructors classified as: Easy, Difficult or Impossible |             |

# %% [markdown]
# ![](https://arpitatechcorner.files.wordpress.com/2020/11/image-13.png)

# %% [markdown]
# ![](https://arpitatechcorner.files.wordpress.com/2020/11/image-15.png)

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*e1h2huKYFWUsR4sGwu47gQ.png)

# %% [markdown]
# ![](https://github.com/datoujinggzj/WhaleDataScienceProject/blob/master/pic/sep.gif?raw=true)

# %% [markdown]
# ![](https://github.com/datoujinggzj/WhaleDataScienceProject/blob/master/pic/13.png?raw=true)

# %% [markdown]
# ### Metadata
#
# You may not be familiar with this concept, but since it is such a heated topic for recent years, you may have heard about it!
#
#
# - What is Metadata？
#
# Metadata， also known as the data about data itself.
#
# - Why it matters in many projects？
#
# When working on projects, we often encounter data with quite high dimensions and many features. In order to do further analysis on them, we must organize these data in a structured way, and Metadata could be a good start for this.
#
# - So, what does it actaully do？
#
# It mainly describes the properties of data (a analysis of the organization and structure of data), also of great significance for future data analysis, visualization, and modeling.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 1</b> Refelction: How should we think through high-dimensional data? Take a minute to think about it first with the tips below!</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <p style="font-size:20px; display:inline">💡</p> Tips：
#
# High-dimensional data, in other words, it means that there are many columns of data, so we should focus around these columns.
#
# We need to think about all the columns with the following aspects:
#
# - role ==> label|feature
# - category ==> infer the data meanings according to the content: car|person|location|numbers
# - level ==> binary|nominal|ordinal|interval|ratio
# - dtype ==> int | float | object...
# - unique ==> number of unique values
# - cardinality ==> high|low|median
# - missing ==> missing data
# - missing_percent ==> missing value percentage
# - imputation ==> any ways to fill in a number for a missing data?
# - keep ==> whether to keep it
#
# </div>

# %%
'Your Answer'

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 2</b>: Build the metadata structure table
#
#
# </div>

# %%
import pandas as pd
import numpy as np
train = pd.read_csv('../../train.gz')
test = pd.read_csv('../../test.gz')

# %%
# combine train test ro have a full set

fullset = "Your Answer"

# %% [markdown]
# Thus, when trying to think through this classifying variables types process:
#
# ```diff
# - role
# + unsertand each column：label|feature
# ```
#
# ```diff
# - category
# + 1. if coulmn name has 'ind', means 'individual'
# + 2. if coulmn name has 'car', means 'car'
# + 3. if coulmn name has 'calc', means 'calculated'
# ```
#
# ```diff
# - level
# + 1. if coulmn name has 'bin' or it is the target, classified as 'binary'
# + 2. elif coulmn name has 'cat' or it is people's id, classified as 'nomial'
# + 3. elif data type is float, classified as 'interval'
# + 4. elif data type is int, classified as 'ordinal'
#
# @ ordinal note: if a data type is `int`, we consider this data to be ordinal, because the arrangement of integers is ordered (2>1, 3>2, etc.), and there exists multiply expressions for integers (although we do not know the specific meaning of the value)

# %% [markdown]
# **The goal is to form a table like the one below:**
#
# This table has 59 rows, which means to analyze each dimension of the data.
#
# **Note: the index of this df is the variable name!**

# %%
'for this below new function meta, the input are train and test, and the output is the metadata table'

# %%
metadata = meta(train,test)

# %%
metadata
# Out:
#                    role    category     level    dtype cardinality  \
# colname
# id                   id       other   nominal    int64      Ignore
# target           target       other    binary   object      Ignore
# ps_ind_01       feature  individual   ordinal    int64           8
# ps_ind_02_cat   feature  individual   nominal    int64           4
# ps_ind_03       feature  individual   ordinal    int64          12
# ps_ind_04_cat   feature  individual   nominal    int64           2
# ps_ind_05_cat   feature  individual   nominal    int64           7
# ps_ind_06_bin   feature  individual    binary    int64           2
# ps_ind_07_bin   feature  individual    binary    int64           2
# ps_ind_08_bin   feature  individual    binary    int64           2
# ps_ind_09_bin   feature  individual    binary    int64           2
# ps_ind_10_bin   feature  individual    binary    int64           2
# ps_ind_11_bin   feature  individual    binary    int64           2
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 3</b>:
#
# Baed on the meta output, Please find out how many features are there for each data role and variable type. The goal is to form the below dataframe!
# </div>

# %%
# start a new line, do not run very block, this is the answer for your to compare!
# Out:
#       role     level  count
# 0  feature    binary     17
# 3  feature   ordinal     16
# 2  feature   nominal     14
# 1  feature  interval      5
# 4  feature     ratio      5
# 5       id   nominal      1
# 6   target    binary      1

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 4 (3 points)</b>:
#
# Please do statistical descriptive analysis on continuous variables based on meta, and use the describe function!
#
# - Which of the continuous variables have missing values?
# - What is the name of the variable with the smallest standard deviation among the continuous variables?
# - What is the name of the variable whose maximum value is greater than 4 in the continuous variable?
#
# </div>

# %%
# tip: use df.describe
stats = "your answer here"
stats
# Out:
#           ps_reg_01     ps_reg_02     ps_reg_03     ps_car_12     ps_car_13  \
# count  1.488028e+06  1.488028e+06  1.488028e+06  1.488028e+06  1.488028e+06
# mean   6.110305e-01  4.395943e-01  5.514848e-01  3.799519e-01  8.134878e-01
# std    2.876763e-01  4.045123e-01  7.938159e-01  5.836187e-02  2.247024e-01
# min    0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00  2.506191e-01
# 25%    4.000000e-01  2.000000e-01  5.250000e-01  3.162278e-01  6.710052e-01
# 50%    7.000000e-01  3.000000e-01  7.211103e-01  3.741657e-01  7.660406e-01
# 75%    9.000000e-01  6.000000e-01  1.001561e+00  4.000000e-01  9.061429e-01
# max    9.000000e-01  1.800000e+00  4.423517e+00  1.264911e+00  4.031301e+00
#
#           ps_car_14     ps_car_15    ps_calc_01    ps_calc_02    ps_calc_03
# count  1.488028e+06  1.488028e+06  1.488028e+06  1.488028e+06  1.488028e+06
# mean   2.763614e-01  3.067355e+00  4.496817e-01  4.501073e-01  4.499718e-01
# ...

# %% [markdown]
# For the questions below, please avoid 'eyeing-out' the answers, but to have efficient answers with your codes!

# %%
# Which of the continuous variables have missing values?

"your code"
# Out:
# Index(['ps_reg_03', 'ps_car_12', 'ps_car_14'], dtype='object')

# %%
# What is the name of the variable with the smallest standard deviation among the continuous variables?

"your code"
# Out:
# 'ps_car_12'

# %%
# What is the name of the variable whose maximum value is greater than 4 in the continuous variable?

"your code"
# Out:
# Index(['ps_reg_03', 'ps_car_13'], dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 5</b>:
#
# From the following code and corresponding results, what do you find?
#
# </div>

# %% [markdown]
# Any findings?

# %%
train.target.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 6</b>:
#
# `from data_management import data_report`
#
# What do you see from the function (data_report) below?
#
# </div>

# %%
from data_management import data_report

# %%
data_report(train,test,metadata,verbose=True)

# %% [markdown]
# Additional Exercise：
#
# If you have spare time, finish 100 Python Pandas puzzle from the doc below to ensure a deeper engagement for the next phase!
#
# Link：https://github.com/ajcr/100-pandas-puzzles/blob/master/100-pandas-puzzles.ipynb
